# %% [markdown]
# # Lab | Functions

# %% [markdown]
# ## Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %%
def initialize_inventory(products):
    inventory = {}
    for product in products:
        item_quantity = int(input(f"Enter the quantity for {product}: "))
        inventory[product] = item_quantity
    return inventory

# %%
# Task 2: Define a function named get_customer_orders that takes no parameters. 
# Inside the function, implement the code for prompting the user to enter the product names using a loop. 
# The function should return the customer_orders set.

def get_customer_orders():
    customer_orders = set()
    keep_adding = "yes"
    
    while keep_adding == "yes":
        order = input("Enter the name of the product you would like to order: ").strip().lower()
        customer_orders.add(order)
        keep_adding = input("Do you want to order another product? (yes/no)").strip().lower()

    return customer_orders

#get_customer_orders()

# %%
# Task 3: Define a function named update_inventory that takes customer_orders and inventory as parameters. 
# Inside the function, implement the code for updating the inventory dictionary based on the customer orders.

def update_inventory(customer_orders, inventory):
    for product in customer_orders:
        if product in inventory:
            inventory[product] -= 1
    return inventory
    
#update_inventory(cust_order, inventory)

# %%
# Task 4: Define a function named calculate_order_statistics that takes customer_orders and products as parameters. 
# Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique 
# products ordered). The function should return these values.

def calculate_order_statistics(customer_orders, products):
    # Total unique products ordered is the size of the set
    total_products_ordered = len(customer_orders)
    
    # Percentage of total product types ordered
    percentage_ordered = (total_products_ordered / len(products)) * 100
    
    # Return both values (as a tuple)
    return total_products_ordered, percentage_ordered

# %%
# Task 5: Define a function named print_order_statistics that takes order_statistics as a parameter. 
# Inside the function, implement the code for printing the order statistics.


def print_order_statistics(order_statistics):
    print("Order Statistics:")
    print(f"Total Products Ordered: {order_statistics[0]}")
    print(f"Percentage of Products Ordered: {order_statistics[1]:.1f}%")

# %%
# Task 6: Define a function named print_updated_inventory that takes inventory as a parameter. 
# Inside the function, implement the code for printing the updated inventory.

def print_updated_inventory(inventory):
    print("\nUpdated Inventory:")
    for product, quantity in inventory.items():
        print(f"{product}: {quantity}")

# %%
# Task 7: Call the functions in the appropriate sequence to execute the program and manage customer orders.

# Define the initial list of available products
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# 1. Initialize the inventory with user-entered quantities
inventory = initialize_inventory(products)

# 2. Get the set of customer orders from the user
customer_orders = get_customer_orders()

# 3. Calculate order statistics
order_stats = calculate_order_statistics(customer_orders, products)

# 4. Print the order statistics
print_order_statistics(order_stats)

# 5. Update the inventory based on customer orders
inventory = update_inventory(customer_orders, inventory)

# 6. Print the updated inventory
print_updated_inventory(inventory)
# Out:
# Enter the quantity for t-shirt:  4
# Enter the quantity for mug:  10
# Enter the quantity for hat:  2
# Enter the quantity for book:  6
# Enter the quantity for keychain:  2
# Enter the name of the product you would like to order:  mug
# Do you want to order another product? (yes/no) yes
# Enter the name of the product you would like to order:  book
# Do you want to order another product? (yes/no) yes
# Enter the name of the product you would like to order:  keychain
# Do you want to order another product? (yes/no) yes
# Enter the name of the product you would like to order:  t-shirt
# Do you want to order another product? (yes/no) yes
# Enter the name of the product you would like to order:  hat
# Do you want to order another product? (yes/no) no
# Order Statistics:
# Total Products Ordered: 5
# Percentage of Products Ordered: 100.0%
#
# Updated Inventory:
# t-shirt: 3
# mug: 9
# hat: 1
# book: 5
# keychain: 1
